# %% [markdown]
# <a href="https://colab.research.google.com/github/bharshasai25-blip/Python_Coding/blob/main/Python__Coding_Project_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
colab_link = 'https://colab.research.google.com/drive/1DK1JR1roYxwaYXDKhd8lXlvno87wlQbs?usp=sharing'

# %% [markdown]
# # **GitHub Repository Link**

# %%
link = 'https://github.com/bharshasai25-blip/Python_Coding/upload/main'

# %% [markdown]
# # **Introduction to Python Programming**

# %% [markdown]
# ## Score Board Operator
# An operator working behind the scoreboard of a inter cohort AlmaBetter cricket tournament, is responsible for updating the scores and points of each team. However, the operator is currently facing a challenge. He has been tasked with updating the total number of points gained by Team London, but he does not possess the necessary programming skills to complete this task.
# According to the tournament's rules, teams are awarded the following points based on the outcome of a match:
#
# * wins: 3 points
# * draws: 1 point
# * losses: 0 points
#
#
#
#
# Team London has played **8 matches** in this tournament. They won **4 matches**, lost **3 matches** and **drew 1**.
# The operator is in need of assistance to calculate the total number of points earned by Team London. As a python expert adept with knowledge of integer, floats and boolean, you can help the operator by writing a solution for the following problem.
#
# What would your approach be?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1. Define your fixed values for points per outcome
win_points = 3
draw_points = 1
loss_points = 0

# %%
# 2. Calculate the total points gained by Team London
# Define the number of matches won, lost, and drew
matches_won = 4
matches_lost = 3
matches_drew = 1

# Calculate total points using the defined point values
london_points = matches_won * win_points + matches_drew * draw_points + matches_lost * loss_points

# %%
# 3. Print the variable london_points to display the result
# Use an f-string for clear output formatting
print(f"Team London's total points are {london_points}")
# Out:
# Team London's total points are 13

# %% [markdown]
# ## Nutrition bar ingredient chart
#
# Imagine you are a data analyst at a nutrition bar manufacturing company. Your department head approaches you with a question. The company produces a nutrition bar that contains **45g of raisins, 65g of almonds, and 30g of apricots**. The head of the manufacturing department wants you to create an ingredient percentage list for the nutrition bar using python.
#
# Equipped with the knowledge of int, float and booleans in python, how would you approach this situation?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Calculate the percentage of raisins and print the variable
# Define the weight of each ingredient in grams
raisins = 45
almonds = 65
apricots = 30

# Calculate the total weight of the nutrition bar
nutrition_bar_total_wt = raisins + almonds + apricots

# Calculate the percentage of raisins in the total weight
raisins_percent = (raisins / nutrition_bar_total_wt) * 100

# Print the raisin content, rounded to two decimal places
print(f'Raisin content =', round(raisins_percent, 2), '%')
# Out:
# Raisin content = 32.14 %

# %%
# Calculate the percentage of almonds and print the variable
# Calculate the percentage of almonds in the total weight
almonds_percent = (almonds / nutrition_bar_total_wt) * 100

# Print the almond content, rounded to two decimal places
print(f'Almond content =', round(almonds_percent, 2), '%')
# Out:
# Almond content = 46.43 %

# %%
# Calculate the percentage of apricots and print the variable
# Calculate the percentage of apricots in the total weight
apricots_percent = (apricots / nutrition_bar_total_wt) * 100

# Print the apricot content, rounded to two decimal places
print(f'Apricot content =', round(apricots_percent, 2), '%')
# Out:
# Apricot content = 21.43 %

# %% [markdown]
# ## Measuring the Accuracy of a Disease Detection Model- Optional
#
# If you're not impressed with these usecases yet, understand that you're just getting started with python. Going forward as a data scientist, you'll be using what you've learned to design machine learning models that just might even save lives!!
#
# Let's say you have created a machine learning model to detect diseases in patients based on their symptoms and medical history. The model has been tested on a dataset of **100 patients**, including **30 with diabetes**, **45 with heart disease**, and **25 with cancer**.
# The model's performance was evaluated in three rounds.
# In the first round, the model correctly **detected diabetes in 25 out of the 30 patients** with the disease.
# In the second round, the model correctly detected **heart disease in 35 out of the 45 patients** with the disease.
# In the final round, the model correctly **detected cancer in 20 out of the 25 patients** with the disease.
#
# The model's accuracy is defined as the percentage of correctly detected cases out of the total number of patient
#
# Assess how accurate your model is across these 3 diseases.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Store the number of heart disease patients
num_heart_patients= 45

# Store the number of diabetes patients
num_diabetes_patients= 30

# Store the number of cancer patients
num_cancer_patients= 25

# Store the number of your correct guesses of heart disease patients
correctly_detected_heart_patients= 35

# Store the number of your correct guesses of diabetes patients
correctly_detected_diabetes_patients= 25

# Store the number of your correct guesses of cancer patients
correctly_detected_cancer_patients= 20

# Print the stored variables to confirm their values
print(f"Number of heart disease patients: {num_heart_patients}")
print(f"Number of diabetes patients: {num_diabetes_patients}")
print(f"Number of cancer patients: {num_cancer_patients}")
print(f"Correctly detected heart patients: {correctly_detected_heart_patients}")
print(f"Correctly detected diabetes patients: {correctly_detected_diabetes_patients}")
print(f"Correctly detected cancer patients: {correctly_detected_cancer_patients}")
# Out:
# Number of heart disease patients: 45
# Number of diabetes patients: 30
# Number of cancer patients: 25
# Correctly detected heart patients: 35
# Correctly detected diabetes patients: 25
# Correctly detected cancer patients: 20

# %% [markdown]
# #### Calculate your accuracy in each of the three cases

# %%
# Print the heart disease detection accuracy
# Calculate the accuracy for heart disease detection
heart_detection_accuracy= (correctly_detected_heart_patients/num_heart_patients)*100
print(f"Accuracy in heart disease detection: {round(heart_detection_accuracy, 2)} %")
# Out:
# Accuracy in heart disease detection: 77.78 %

# %%
# Print the diabetes detection accuracy
# Calculate the accuracy for diabetes detection
diabetes_detection_accuracy= (correctly_detected_diabetes_patients/num_diabetes_patients)*100
print(f"Accuracy in diabetes detection: {round(diabetes_detection_accuracy, 2)} %")
# Out:
# Accuracy in diabetes detection: 83.33 %

# %%
# Print the cancer detection accuracy
# Calculate the accuracy for cancer detection
cancer_detection_accuracy= (correctly_detected_cancer_patients/num_cancer_patients)*100
print(f"Accuracy in cancer detection: {cancer_detection_accuracy:.2f} %")
# Out:
# Accuracy in cancer detection: 80.00 %

# %%
# Print the overall accuracy of your model # Average of accuracy in 3 rounds
# Calculate the overall accuracy of the model by summing correct detections and total patients
overall_accuracy= (correctly_detected_heart_patients+correctly_detected_diabetes_patients+correctly_detected_cancer_patients)/(num_heart_patients+num_diabetes_patients+num_cancer_patients)*100
print(f"Overall accuracy of the model: {overall_accuracy:.2f} %")
# Out:
# Overall accuracy of the model: 80.00 %

# %% [markdown]
# # **Data Types in Python**

# %% [markdown]
# ## Solving Algebra the Cool Way 😎

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You must remember the algebraic equations and functions you came across during your school days. If you do, you also must remember how tedious it was to do solve them manually. 😫
# Consider a quadratic function:
#
# ***f(x)=x^2+3x-4***
#
# Find the value of f(x) at x =3 , x=-2, and x=4
#
# Doing this manually like the old days would be a tedious job 😞. But now you have python at your disposal 🙂 !
# How would you approach this problem using what you have learned?

# %%
# Calculate the value of the function f(x) at x = 3
func_evaluated = lambda x: (x^2)+(3*x)-4
print(func_evaluated(3))
# Out:
# 6

# %%
# Calculate the value of the function f(x) at x = -2
print(func_evaluated(-2))
# Out:
# -14

# %%
# Calculate the value of the function f(x) at x = 4
print(func_evaluated(4))
# Out:
# 14

# %%
#Check if func_evaluated_at_3 >= func_evaluated_at_minus2
print(True if func_evaluated(3) >= func_evaluated(-2) else False)
# Out:
# True

# %%
#Check if value of f(x) at 3,-2 or 4 is equal to 0 or not
print(True if func_evaluated(3) == 0 else False)
print(True if func_evaluated(-2) == 0 else False)
print(True if func_evaluated(4) == 0 else False)
# Out:
# False
# False
# False
